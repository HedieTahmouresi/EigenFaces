# %% [markdown]
# # Eigenfaces: PCA-based face recognition
#
# Clean narrative notebook. Imports from `src/` -- this is not where development happens.
#
# TODO: written last, after the experiments in `experiments/` are complete.
